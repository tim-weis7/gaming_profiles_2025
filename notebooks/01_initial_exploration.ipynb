# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

import pandas as pd
import matplotlib.pyplot as plt


from load_data import load_table

# %%
df = load_table("steam.players_clean", limit=1000)
# Out:
# Tabelle 'steam.players_clean' erfolgreich geladen. Zeilen: 1000

# %%
# Übersicht
print(df.head())
print(df.info())
print(df.describe())
# Out:
#            player_id     country             created
# 0  76561198287452552      Brazil 2016-03-02 06:14:20
# 1  76561198040436563      Israel 2011-04-10 17:10:06
# 2  76561198049686270     Unknown 2011-09-28 21:43:59
# 3  76561198155814250  Kazakhstan 2014-09-24 19:52:47
# 4  76561198119605821     Unknown 2013-12-26 00:25:50
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  1000 non-null   object
#  1   country    1000 non-null   object
#  2   created    927 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 23.6+ KB
# None
#                              created
# count                            927
# mean   2015-03-03 08:02:39.049622272
# min              2003-09-12 14:27:03
# 25%              2012-12-27 22:00:28
# 50%              2015-04-25 04:12:53
# 75%              2017-08-20 05:35:23
# ...

# %%
unknown_count = df[df['country'] == 'Unknown'].shape[0]
print("Anzahl Unknown: ", unknown_count)
# Out:
# Anzahl Unknown:  385

# %%
df['country'].value_counts()
# Out:
# country
# Unknown               385
# Russian Federation    105
# China                  57
# United States          51
# Brazil                 33
#                      ...
# Bermuda                 1
# New Zealand             1
# Slovakia                1
# Congo                   1
# Zambia                  1
# Name: count, Length: 89, dtype: int64
